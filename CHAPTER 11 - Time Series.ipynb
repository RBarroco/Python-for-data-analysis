# %%
import numpy as np
import pandas as pd

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2020, 5, 16, 18, 40, 8, 901989)

# %%
now.year, now.month, now.day
# Out:
# (2020, 5, 16)

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)

# %%
delta
# Out:
# datetime.timedelta(days=926, seconds=56700)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
from datetime import timedelta

# %%
start = datetime(2011, 1, 7)

# %%
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %% [markdown]
# **Converting Between String and Datetime**

# %%
stamp = datetime(2011, 1, 3)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime('%Y-%m-%d')
# Out:
# '2011-01-03'

# %%
value = '2011-01-03'

# %%
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ['7/6/2011', '8/6/2011']

# %%
 [datetime.strptime(x, '%m/%d/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %%
from dateutil.parser import parse

# %%
parse('2011-01-03')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
parse('Jan 31, 1997 10:45 PM')
# Out:
# datetime.datetime(1997, 1, 31, 22, 45)

# %%
parse('6/12/2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 12, 6, 0, 0)

# %%
datestrs = ['2011-07-06 12:00:00', '2011-08-06 00:00:00']

# %%
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
idx = pd.to_datetime(datestrs + [None])

# %%
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
pd.isnull(idx)
# Out:
# array([False, False,  True])

# %% [markdown]
# **Time Series Basics**

# %%
from datetime import datetime

# %%
dates = [datetime(2011, 1, 2),  datetime(2011, 1, 5),
         datetime(2011, 1, 7),  datetime(2011, 1, 8), 
         datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.randn(6), index=dates)

# %%
ts
# Out:
# 2011-01-02   -2.026640
# 2011-01-05    0.928508
# 2011-01-07    0.410482
# 2011-01-08   -0.730698
# 2011-01-10    0.103034
# 2011-01-12   -0.011799
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts + ts[::2]
# Out:
# 2011-01-02   -4.053280
# 2011-01-05         NaN
# 2011-01-07    0.820964
# 2011-01-08         NaN
# 2011-01-10    0.206068
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
stamp = ts.index[0]

# %%
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %% [markdown]
# **Indexing, Selection, Subsetting**

# %%
stamp = ts.index[2]

# %%
ts[stamp]
# Out:
# 0.4104817842364375

# %%
ts['1/10/2011']
# Out:
# 0.10303379646482157

# %%
ts['20110110']
# Out:
# 0.10303379646482157

# %%
longer_ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
longer_ts
# Out:
# 2000-01-01    0.390907
# 2000-01-02    1.199077
# 2000-01-03    1.418188
# 2000-01-04   -0.104986
# 2000-01-05    0.117114
#                 ...
# 2002-09-22   -0.647840
# 2002-09-23    0.516487
# 2002-09-24    1.317166
# 2002-09-25   -0.061259
# 2002-09-26   -1.229005
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts['2001']
# Out:
# 2001-01-01    0.020363
# 2001-01-02    0.228868
# 2001-01-03   -0.543994
# 2001-01-04    0.273882
# 2001-01-05   -1.899583
#                 ...
# 2001-12-27   -0.233289
# 2001-12-28    0.021196
# 2001-12-29    1.191649
# 2001-12-30    1.604483
# 2001-12-31   -0.944981
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts['2001-05']
# Out:
# 2001-05-01    0.347611
# 2001-05-02    1.606792
# 2001-05-03   -0.045097
# 2001-05-04    1.632907
# 2001-05-05    0.018457
# 2001-05-06   -1.904971
# 2001-05-07   -0.683128
# 2001-05-08   -0.828652
# 2001-05-09   -0.683794
# 2001-05-10    0.132253
# 2001-05-11   -0.661818
# 2001-05-12   -1.469983
# 2001-05-13   -1.264217
# 2001-05-14   -0.955206
# 2001-05-15    0.059240
# 2001-05-16    0.825765
# 2001-05-17   -0.238000
# 2001-05-18   -0.284163
# 2001-05-19   -0.761925
# 2001-05-20   -0.746965
# 2001-05-21    0.207773
# 2001-05-22    1.958048
# 2001-05-23    1.479834
# 2001-05-24   -1.884618
# 2001-05-25    0.283653
# 2001-05-26   -0.479482
# 2001-05-27   -0.379370
# 2001-05-28   -0.850327
# 2001-05-29   -1.192436
# 2001-05-30   -0.106620
# 2001-05-31   -0.165498
# Freq: D, dtype: float64

# %%
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07    0.410482
# 2011-01-08   -0.730698
# 2011-01-10    0.103034
# 2011-01-12   -0.011799
# dtype: float64

# %%
ts
# Out:
# 2011-01-02   -2.026640
# 2011-01-05    0.928508
# 2011-01-07    0.410482
# 2011-01-08   -0.730698
# 2011-01-10    0.103034
# 2011-01-12   -0.011799
# dtype: float64

# %%
ts['1/6/2011':'1/11/2011']
# Out:
# 2011-01-07    0.410482
# 2011-01-08   -0.730698
# 2011-01-10    0.103034
# dtype: float64

# %%
ts.truncate(after='1/9/2011')
# Out:
# 2011-01-02   -2.026640
# 2011-01-05    0.928508
# 2011-01-07    0.410482
# 2011-01-08   -0.730698
# dtype: float64

# %%
dates = pd.date_range('1/1/2000', periods=100, freq='W-WED')

# %%
dates
# Out:
# DatetimeIndex(['2000-01-05', '2000-01-12', '2000-01-19', '2000-01-26',
#                '2000-02-02', '2000-02-09', '2000-02-16', '2000-02-23',
#                '2000-03-01', '2000-03-08', '2000-03-15', '2000-03-22',
#                '2000-03-29', '2000-04-05', '2000-04-12', '2000-04-19',
#                '2000-04-26', '2000-05-03', '2000-05-10', '2000-05-17',
#                '2000-05-24', '2000-05-31', '2000-06-07', '2000-06-14',
#                '2000-06-21', '2000-06-28', '2000-07-05', '2000-07-12',
#                '2000-07-19', '2000-07-26', '2000-08-02', '2000-08-09',
#                '2000-08-16', '2000-08-23', '2000-08-30', '2000-09-06',
#                '2000-09-13', '2000-09-20', '2000-09-27', '2000-10-04',
#                '2000-10-11', '2000-10-18', '2000-10-25', '2000-11-01',
#                '2000-11-08', '2000-11-15', '2000-11-22', '2000-11-29',
#                '2000-12-06', '2000-12-13', '2000-12-20', '2000-12-27',
#                '2001-01-03', '2001-01-10', '2001-01-17', '2001-01-24',
#                '2001-01-31', '2001-02-07', '2001-02-14', '2001-02-21',
#                '2001-02-28', '2001-03-07', '2001-03-14', '2001-03-21',
#                '2001-03-28', '2001-04-04', '2001-04-11', '2001-04-18',
#                '2001-04-25', '2001-05-02', '2001-05-09', '2001-05-16',
#                '2001-05-23', '2001-05-30', '2001-06-06', '2001-06-13',
#                '2001-06-20', '2001-06-27', '2001-07-04', '2001-07-11',
#                '2001-07-18', '2001-07-25', '2001-08-01', '2001-08-08',
#                '2001-08-15', '2001-08-22', '2001-08-29', '2001-09-05',
#                '2001-09-12', '2001-09-19', '2001-09-26', '2001-10-03',
#                '2001-10-10', '2001-10-17', '2001-10-24', '2001-10-31',
#                '2001-11-07', '2001-11-14', '2001-11-21', '2001-11-28'],
#               dtype='datetime64[ns]', freq='W-WED')

# %%
long_df = pd.DataFrame(np.random.randn(100, 4),
         index=dates,
         columns=['Colorado', 'Texas','New York', 'Ohio'])

# %%
long_df.loc['5-2001']
# Out:
#             Colorado     Texas  New York      Ohio
# 2001-05-02  0.466796  1.899334  1.670509  0.291000
# 2001-05-09  0.017233  0.157069 -0.145875  1.313986
# 2001-05-16 -0.125053 -0.664272  0.387159  0.154989
# 2001-05-23 -0.658961 -1.028570 -0.170391  0.856351
# 2001-05-30 -1.620807  0.211606 -0.330773  1.503182

# %% [markdown]
# **Time Series with Duplicate Indices**

# %%
dates = pd.DatetimeIndex(['1/1/2000', '1/2/2000', '1/2/2000', '1/2/2000', '1/3/2000'])

# %%
dup_ts = pd.Series(np.arange(5), index=dates)

# %%
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int32

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts['1/3/2000']
# Out:
# 4

# %%
dup_ts['1/2/2000'] # duplicated
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int32

# %%
grouped = dup_ts.groupby(level=0)

# %%
grouped.mean()
# Out:
# 2000-01-01    0
# 2000-01-02    2
# 2000-01-03    4
# dtype: int32

# %%
grouped.count()
# Out:
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-03    1
# dtype: int64

# %% [markdown]
# **Date Ranges, Frequencies, and Shifting**

# %%
ts
# Out:
# 2011-01-02   -2.026640
# 2011-01-05    0.928508
# 2011-01-07    0.410482
# 2011-01-08   -0.730698
# 2011-01-10    0.103034
# 2011-01-12   -0.011799
# dtype: float64

# %%
resampler = ts.resample('D')

# %% [markdown]
# **Generating Date Ranges**

# %%
index = pd.date_range('2012-04-01', '2012-06-01')

# %%
index
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2012-04-01', periods=20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end='2012-06-01', periods=20)
# Out:
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2000-01-01', '2000-12-01', freq='BM')
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30'],
#               dtype='datetime64[ns]', freq='BM')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5)
# Out:
# DatetimeIndex(['2012-05-02 12:56:31', '2012-05-03 12:56:31',
#                '2012-05-04 12:56:31', '2012-05-05 12:56:31',
#                '2012-05-06 12:56:31'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5, normalize=True)
# Out:
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **Frequencies and Date Offsets**

# %%
from pandas.tseries.offsets import Hour, Minute

# %%
hour = Hour()

# %%
four_hours = Hour(4)

# %%
four_hours
# Out:
# <4 * Hours>

# %%
pd.date_range('2000-01-01', '2000-01-03 23:59', freq='4h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
Hour(2) + Minute(30)
# Out:
# <150 * Minutes>

# %%
pd.date_range('2000-01-01', periods=10, freq='1h30min')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90T')

# %% [markdown]
# **Week of month dates**

# %%
rng = pd.date_range('2012-01-01', '2012-09-01', freq='WOM-3FRI')

# %%
list(rng)
# Out:
# [Timestamp('2012-01-20 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-02-17 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-03-16 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-04-20 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-05-18 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-06-15 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-07-20 00:00:00', freq='WOM-3FRI'),
#  Timestamp('2012-08-17 00:00:00', freq='WOM-3FRI')]

# %% [markdown]
# **Shifting (Leading and Lagging) Data**

# %%
ts = pd.Series(np.random.randn(4), index=pd.date_range('1/1/2000', periods=4, freq='M'))

# %%
ts
# Out:
# 2000-01-31    1.546632
# 2000-02-29   -0.523118
# 2000-03-31   -1.276746
# 2000-04-30   -0.506638
# Freq: M, dtype: float64

# %%
ts.shift(2)
# Out:
# 2000-01-31         NaN
# 2000-02-29         NaN
# 2000-03-31    1.546632
# 2000-04-30   -0.523118
# Freq: M, dtype: float64

# %%
ts.shift(-2)
# Out:
# 2000-01-31   -1.276746
# 2000-02-29   -0.506638
# 2000-03-31         NaN
# 2000-04-30         NaN
# Freq: M, dtype: float64

# %%
ts / ts.shift(1) - 1
# Out:
# 2000-01-31         NaN
# 2000-02-29   -1.338231
# 2000-03-31    1.440644
# 2000-04-30   -0.603180
# Freq: M, dtype: float64

# %%
ts.shift(2, freq='M')
# Out:
# 2000-03-31    1.546632
# 2000-04-30   -0.523118
# 2000-05-31   -1.276746
# 2000-06-30   -0.506638
# Freq: M, dtype: float64

# %%
ts.shift(3, freq='D')
# Out:
# 2000-02-03    1.546632
# 2000-03-03   -0.523118
# 2000-04-03   -1.276746
# 2000-05-03   -0.506638
# dtype: float64

# %%
ts.shift(1, freq='90T')
# Out:
# 2000-01-31 01:30:00    1.546632
# 2000-02-29 01:30:00   -0.523118
# 2000-03-31 01:30:00   -1.276746
# 2000-04-30 01:30:00   -0.506638
# Freq: M, dtype: float64

# %% [markdown]
# **Shifting dates with offsets**

# %%
from pandas.tseries.offsets import Day, MonthEnd

# %%
now = datetime(2011, 11, 17)

# %%
now + 3 * Day()
# Out:
# Timestamp('2011-11-20 00:00:00')

# %%
now + MonthEnd()
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
now + MonthEnd(2)
# Out:
# Timestamp('2011-12-31 00:00:00')

# %%
offset = MonthEnd()

# %%
offset.rollforward(now)
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
offset.rollback(now)
# Out:
# Timestamp('2011-10-31 00:00:00')

# %%
ts = pd.Series(np.random.randn(20), index=pd.date_range('1/15/2000', periods=20, freq='4d'))

# %%
ts
# Out:
# 2000-01-15   -1.196434
# 2000-01-19   -0.000254
# 2000-01-23    0.434598
# 2000-01-27   -2.289870
# 2000-01-31    0.685791
# 2000-02-04    0.853792
# 2000-02-08    0.565209
# 2000-02-12    0.281428
# 2000-02-16   -1.547944
# 2000-02-20   -0.367406
# 2000-02-24    0.725790
# 2000-02-28   -0.350308
# 2000-03-03   -0.648475
# 2000-03-07    0.363964
# 2000-03-11   -1.431413
# 2000-03-15    0.067801
# 2000-03-19    0.833403
# 2000-03-23   -0.542687
# 2000-03-27    0.990577
# 2000-03-31   -0.220708
# Freq: 4D, dtype: float64

# %%
ts.groupby(offset.rollforward).mean()
# Out:
# 2000-01-31   -0.473234
# 2000-02-29    0.022937
# 2000-03-31   -0.073442
# dtype: float64

# %%
ts
# Out:
# 2000-01-15   -1.196434
# 2000-01-19   -0.000254
# 2000-01-23    0.434598
# 2000-01-27   -2.289870
# 2000-01-31    0.685791
# 2000-02-04    0.853792
# 2000-02-08    0.565209
# 2000-02-12    0.281428
# 2000-02-16   -1.547944
# 2000-02-20   -0.367406
# 2000-02-24    0.725790
# 2000-02-28   -0.350308
# 2000-03-03   -0.648475
# 2000-03-07    0.363964
# 2000-03-11   -1.431413
# 2000-03-15    0.067801
# 2000-03-19    0.833403
# 2000-03-23   -0.542687
# 2000-03-27    0.990577
# 2000-03-31   -0.220708
# Freq: 4D, dtype: float64

# %%
ts.resample('M').mean()
# Out:
# 2000-01-31   -0.473234
# 2000-02-29    0.022937
# 2000-03-31   -0.073442
# Freq: M, dtype: float64

# %% [markdown]
# **11.4 Time Zone Handling**

# %%
import pytz

# %%
pytz.common_timezones[-5:]
# Out:
# ['US/Eastern', 'US/Hawaii', 'US/Mountain', 'US/Pacific', 'UTC']

# %%
tz = pytz.timezone('America/New_York')

# %%
tz
# Out:
# <DstTzInfo 'America/New_York' LMT-1 day, 19:04:00 STD>

# %% [markdown]
# **Time Zone Localization and Conversion**

# %%
rng = pd.date_range('3/9/2012 9:30', periods=6, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-03-09 09:30:00    0.131507
# 2012-03-10 09:30:00   -0.034194
# 2012-03-11 09:30:00   -1.459664
# 2012-03-12 09:30:00   -0.350478
# 2012-03-13 09:30:00    1.316299
# 2012-03-14 09:30:00   -0.918515
# Freq: D, dtype: float64

# %%
print(ts.index.tz)
# Out:
# None

# %%
pd.date_range('3/9/2012 9:30', periods=10, freq='D', tz='UTC')
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00', '2012-03-16 09:30:00+00:00',
#                '2012-03-17 09:30:00+00:00', '2012-03-18 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')

# %%
ts
# Out:
# 2012-03-09 09:30:00    0.131507
# 2012-03-10 09:30:00   -0.034194
# 2012-03-11 09:30:00   -1.459664
# 2012-03-12 09:30:00   -0.350478
# 2012-03-13 09:30:00    1.316299
# 2012-03-14 09:30:00   -0.918515
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-09 09:30:00+00:00    0.131507
# 2012-03-10 09:30:00+00:00   -0.034194
# 2012-03-11 09:30:00+00:00   -1.459664
# 2012-03-12 09:30:00+00:00   -0.350478
# 2012-03-13 09:30:00+00:00    1.316299
# 2012-03-14 09:30:00+00:00   -0.918515
# Freq: D, dtype: float64

# %%
ts_utc.index
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')

# %%
ts_utc.tz_convert('America/New_York')
# Out:
# 2012-03-09 04:30:00-05:00    0.131507
# 2012-03-10 04:30:00-05:00   -0.034194
# 2012-03-11 05:30:00-04:00   -1.459664
# 2012-03-12 05:30:00-04:00   -0.350478
# 2012-03-13 05:30:00-04:00    1.316299
# 2012-03-14 05:30:00-04:00   -0.918515
# Freq: D, dtype: float64

# %%
ts_eastern = ts.tz_localize('America/New_York')

# %%
ts_eastern.tz_convert('UTC')
# Out:
# 2012-03-09 14:30:00+00:00    0.131507
# 2012-03-10 14:30:00+00:00   -0.034194
# 2012-03-11 13:30:00+00:00   -1.459664
# 2012-03-12 13:30:00+00:00   -0.350478
# 2012-03-13 13:30:00+00:00    1.316299
# 2012-03-14 13:30:00+00:00   -0.918515
# Freq: D, dtype: float64

# %%
ts_eastern.tz_convert('Europe/Berlin')
# Out:
# 2012-03-09 15:30:00+01:00    0.131507
# 2012-03-10 15:30:00+01:00   -0.034194
# 2012-03-11 14:30:00+01:00   -1.459664
# 2012-03-12 14:30:00+01:00   -0.350478
# 2012-03-13 14:30:00+01:00    1.316299
# 2012-03-14 14:30:00+01:00   -0.918515
# Freq: D, dtype: float64

# %%
ts.index.tz_localize('Asia/Shanghai')
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+08:00', '2012-03-10 09:30:00+08:00',
#                '2012-03-11 09:30:00+08:00', '2012-03-12 09:30:00+08:00',
#                '2012-03-13 09:30:00+08:00', '2012-03-14 09:30:00+08:00'],
#               dtype='datetime64[ns, Asia/Shanghai]', freq='D')

# %% [markdown]
# **Operations with Time Zone−Aware Timestamp Objects**

# %%
stamp = pd.Timestamp('2011-03-12 04:00')

# %%
stamp_utc = stamp.tz_localize('utc')

# %%
stamp_utc.tz_convert('America/New_York')
# Out:
# Timestamp('2011-03-11 23:00:00-0500', tz='America/New_York')

# %%
stamp_moscow = pd.Timestamp('2011-03-12 04:00', tz='Europe/Moscow')

# %%
stamp_moscow
# Out:
# Timestamp('2011-03-12 04:00:00+0300', tz='Europe/Moscow')

# %%
stamp_utc.value
# Out:
# 1299902400000000000

# %%
stamp_utc.tz_convert('America/New_York').value
# Out:
# 1299902400000000000

# %%
from pandas.tseries.offsets import Hour

# %%
stamp = pd.Timestamp('2012-03-12 01:30', tz='US/Eastern')

# %%
stamp
# Out:
# Timestamp('2012-03-12 01:30:00-0400', tz='US/Eastern')

# %%
stamp + Hour()
# Out:
# Timestamp('2012-03-12 02:30:00-0400', tz='US/Eastern')

# %% [markdown]
# When performing time arithmetic using pandas’s DateOffset objects, pandas
# respects daylight saving time transitions where possible. Here we construct time‐
# stamps that occur right before DST transitions (forward and backward). First, 30
# minutes before transitioning to DST

# %%
stamp = pd.Timestamp('2012-11-04 00:30', tz='US/Eastern')

# %%
stamp
# Out:
# Timestamp('2012-11-04 00:30:00-0400', tz='US/Eastern')

# %%
stamp + 2 * Hour()
# Out:
# Timestamp('2012-11-04 01:30:00-0500', tz='US/Eastern')

# %% [markdown]
# **Operations Between Different Time Zones**

# %%
rng = pd.date_range('3/7/2012 9:30', periods=10, freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2012-03-07 09:30:00', '2012-03-08 09:30:00',
#                '2012-03-09 09:30:00', '2012-03-12 09:30:00',
#                '2012-03-13 09:30:00', '2012-03-14 09:30:00',
#                '2012-03-15 09:30:00', '2012-03-16 09:30:00',
#                '2012-03-19 09:30:00', '2012-03-20 09:30:00'],
#               dtype='datetime64[ns]', freq='B')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-03-07 09:30:00    0.980611
# 2012-03-08 09:30:00    0.608431
# 2012-03-09 09:30:00    0.207558
# 2012-03-12 09:30:00    0.176308
# 2012-03-13 09:30:00    0.134269
# 2012-03-14 09:30:00   -1.260232
# 2012-03-15 09:30:00   -0.029594
# 2012-03-16 09:30:00    1.906606
# 2012-03-19 09:30:00    1.061884
# 2012-03-20 09:30:00   -1.511003
# Freq: B, dtype: float64

# %%
ts1 = ts[:7].tz_localize('Europe/London')

# %%
ts2 = ts1[2:].tz_convert('Europe/Moscow')

# %%
result = ts1 + ts2

# %%
result.index
# Out:
# DatetimeIndex(['2012-03-07 09:30:00+00:00', '2012-03-08 09:30:00+00:00',
#                '2012-03-09 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='B')

# %% [markdown]
# **Periods and Period Arithmetic**

# %% [markdown]
# Periods represent timespans, like days, months, quarters, or years. The Period class
# represents this data type, requiring a string or integer and a frequency

# %%
p = pd.Period(2007, freq='A-DEC')

# %%
p
# Out:
# Period('2007', 'A-DEC')

# %%
p + 5
# Out:
# Period('2012', 'A-DEC')

# %%
p - 2
# Out:
# Period('2005', 'A-DEC')

# %%
pd.Period('2014', freq='A-DEC') - p
# Out:
# <7 * YearEnds: month=12>

# %%
rng = pd.period_range('2000-01-01', '2000-06-30', freq='M')

# %%
rng
# Out:
# PeriodIndex(['2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06'], dtype='period[M]', freq='M')

# %%
pd.Series(np.random.randn(6), index=rng)
# Out:
# 2000-01    0.053475
# 2000-02    0.742552
# 2000-03    2.033821
# 2000-04    0.205770
# 2000-05   -1.781233
# 2000-06    0.578664
# Freq: M, dtype: float64

# %%
values = ['2001Q3', '2002Q2', '2003Q1']

# %%
index = pd.PeriodIndex(values, freq='Q-DEC')

# %%
index
# Out:
# PeriodIndex(['2001Q3', '2002Q2', '2003Q1'], dtype='period[Q-DEC]', freq='Q-DEC')

# %% [markdown]
# **Period Frequency Conversion**

# %%
p = pd.Period('2007', freq='A-DEC')

# %%
p
# Out:
# Period('2007', 'A-DEC')

# %%
p.asfreq('M', how='start')
# Out:
# Period('2007-01', 'M')

# %%
p.asfreq('M', how='end')
# Out:
# Period('2007-12', 'M')

# %%
p = pd.Period('2007', freq='A-JUN')

# %%
p
# Out:
# Period('2007', 'A-JUN')

# %%
p.asfreq('M', 'start')
# Out:
# Period('2006-07', 'M')

# %%
p.asfreq('M', 'end')
# Out:
# Period('2007-06', 'M')

# %%
p = pd.Period('Aug-2007', 'M')

# %%
p.asfreq('A-JUN')
# Out:
# Period('2008', 'A-JUN')

# %%
rng = pd.period_range('2006', '2009', freq='A-DEC')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2006    2.429154
# 2007    0.489771
# 2008   -0.154681
# 2009   -0.483268
# Freq: A-DEC, dtype: float64

# %%
ts.asfreq('M', how='start')
# Out:
# 2006-01    2.429154
# 2007-01    0.489771
# 2008-01   -0.154681
# 2009-01   -0.483268
# Freq: M, dtype: float64

# %%
ts.asfreq('B', how='end')
# Out:
# 2006-12-29    2.429154
# 2007-12-31    0.489771
# 2008-12-31   -0.154681
# 2009-12-31   -0.483268
# Freq: B, dtype: float64

# %% [markdown]
# **Quarterly Period Frequencies**

# %%
p = pd.Period('2012Q4', freq='Q-JAN')

# %%
p
# Out:
# Period('2012Q4', 'Q-JAN')

# %%
p.asfreq('D', 'start')
# Out:
# Period('2011-11-01', 'D')

# %%
p.asfreq('D', 'end')
# Out:
# Period('2012-01-31', 'D')

# %%
p4pm = (p.asfreq('B', 'e') - 1).asfreq('T', 's') + 16 * 60

# %%
p4pm
# Out:
# Period('2012-01-30 16:00', 'T')

# %%
p4pm.to_timestamp()
# Out:
# Timestamp('2012-01-30 16:00:00')

# %%
rng = pd.period_range('2011Q3', '2012Q4', freq='Q-JAN')

# %%
ts = pd.Series(np.arange(len(rng)), index=rng)

# %%
ts
# Out:
# 2006    0
# 2007    1
# 2008    2
# 2009    3
# Freq: A-DEC, dtype: int32

# %%
new_rng = (rng.asfreq('B', 'e') - 1).asfreq('T', 's') + 16 * 60

# %%
ts.index = new_rng.to_timestamp()

# %%
ts
# Out:
# 2006-12-28 16:00:00    0
# 2007-12-28 16:00:00    1
# 2008-12-30 16:00:00    2
# 2009-12-30 16:00:00    3
# dtype: int32

# %% [markdown]
# **Converting Timestamps to Periods (and Back)**

# %% [markdown]
# Series and DataFrame objects indexed by timestamps can be converted to periods
# with the to_period method:

# %%
rng = pd.date_range('2000-01-01', periods=3, freq='M')

# %%
ts = pd.Series(np.random.randn(3), index=rng)

# %%
ts
# Out:
# 2000-01-31   -0.239412
# 2000-02-29    0.376743
# 2000-03-31    1.138392
# Freq: M, dtype: float64

# %%
pts = ts.to_period()
pts
# Out:
# 2000-01   -0.239412
# 2000-02    0.376743
# 2000-03    1.138392
# Freq: M, dtype: float64

# %%
rng = pd.date_range('1/29/2000', periods=6, freq='D')

# %%
ts2 = pd.Series(np.random.randn(6), index=rng)

# %%
ts2
# Out:
# 2000-01-29   -0.074994
# 2000-01-30   -1.943336
# 2000-01-31    0.181902
# 2000-02-01   -0.036568
# 2000-02-02    0.594837
# 2000-02-03   -0.953247
# Freq: D, dtype: float64

# %%
ts2.to_period('M')
# Out:
# 2000-01   -0.074994
# 2000-01   -1.943336
# 2000-01    0.181902
# 2000-02   -0.036568
# 2000-02    0.594837
# 2000-02   -0.953247
# Freq: M, dtype: float64

# %%
pts = ts2.to_period()

# %%
pts
# Out:
# 2000-01-29   -0.074994
# 2000-01-30   -1.943336
# 2000-01-31    0.181902
# 2000-02-01   -0.036568
# 2000-02-02    0.594837
# 2000-02-03   -0.953247
# Freq: D, dtype: float64

# %%
pts.to_timestamp(how='end')
# Out:
# 2000-01-29 23:59:59.999999999   -0.074994
# 2000-01-30 23:59:59.999999999   -1.943336
# 2000-01-31 23:59:59.999999999    0.181902
# 2000-02-01 23:59:59.999999999   -0.036568
# 2000-02-02 23:59:59.999999999    0.594837
# 2000-02-03 23:59:59.999999999   -0.953247
# Freq: D, dtype: float64

# %% [markdown]
# **Creating a PeriodIndex from Arrays**

# %% [markdown]
# Fixed frequency datasets are sometimes stored with timespan information spread
# across multiple columns. For example, in this macroeconomic dataset, the year and
# quarter are in different columns:

# %%
data = pd.read_csv('./book-support/examples/macrodata.csv')

# %%
data
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# 0     28.980   139.7      2.82    5.8  177.146  0.00     0.00
# 1     29.150   141.7      3.08    5.1  177.830  2.34     0.74
# 2     29.350   140.5      3.82    5.3  178.657  2.74     1.09
# 3     29.370   140.0      4.33    5.6  179.386  0.27     4.06
# 4     29.540   139.6      3.50    5.2  180.007  2.31     1.19
# ..       ...     ...       ...    ...      ...   ...      ...
# 198  216.889  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  212.174  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  212.671  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  214.469  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  216.385  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
data.head(5)
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
data.year
# Out:
# 0      1959.0
# 1      1959.0
# 2      1959.0
# 3      1959.0
# 4      1960.0
#         ...
# 198    2008.0
# 199    2008.0
# 200    2009.0
# 201    2009.0
# 202    2009.0
# Name: year, Length: 203, dtype: float64

# %%
data.quarter
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      1.0
#       ...
# 198    3.0
# 199    4.0
# 200    1.0
# 201    2.0
# 202    3.0
# Name: quarter, Length: 203, dtype: float64

# %%
index = pd.PeriodIndex(year=data.year, quarter=data.quarter, freq='Q-DEC')

# %%
index
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='period[Q-DEC]', length=203, freq='Q-DEC')

# %%
data.index = index

# %%
data.infl
# Out:
# 1959Q1    0.00
# 1959Q2    2.34
# 1959Q3    2.74
# 1959Q4    0.27
# 1960Q1    2.31
#           ...
# 2008Q3   -3.16
# 2008Q4   -8.79
# 2009Q1    0.94
# 2009Q2    3.37
# 2009Q3    3.56
# Freq: Q-DEC, Name: infl, Length: 203, dtype: float64

# %% [markdown]
#  **Resampling and Frequency Conversion**

# %%
rng = pd.date_range('2000-01-01', periods=100, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2000-01-01    1.283536
# 2000-01-02    1.185154
# 2000-01-03    0.156266
# 2000-01-04    0.015462
# 2000-01-05   -1.158468
#                 ...
# 2000-04-05    1.274776
# 2000-04-06    2.296517
# 2000-04-07   -2.849887
# 2000-04-08   -1.070977
# 2000-04-09   -1.153776
# Freq: D, Length: 100, dtype: float64

# %%
ts.resample('M').mean()
# Out:
# 2000-01-31   -0.097056
# 2000-02-29   -0.487900
# 2000-03-31    0.192892
# 2000-04-30   -0.053487
# Freq: M, dtype: float64

# %%
ts.resample('M', kind='period').mean()
# Out:
# 2000-01   -0.097056
# 2000-02   -0.487900
# 2000-03    0.192892
# 2000-04   -0.053487
# Freq: M, dtype: float64

# %% [markdown]
# **Downsampling**

# %%
rng = pd.date_range('2000-01-01', periods=12, freq='T')|

# %%
ts = pd.Series(np.arange(12), index=rng)

# %%
ts
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:01:00     1
# 2000-01-01 00:02:00     2
# 2000-01-01 00:03:00     3
# 2000-01-01 00:04:00     4
# 2000-01-01 00:05:00     5
# 2000-01-01 00:06:00     6
# 2000-01-01 00:07:00     7
# 2000-01-01 00:08:00     8
# 2000-01-01 00:09:00     9
# 2000-01-01 00:10:00    10
# 2000-01-01 00:11:00    11
# Freq: T, dtype: int32

# %%
ts.resample('5min', closed='right').sum()
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5T, dtype: int32

# %% [markdown]
# The frequency you pass defines bin edges in five-minute increments. By default,
# the left bin edge is inclusive, so the 00:00 value is included in the 00:00 to 00:05
# interval.1
#  Passing closed='right' changes the interval to be closed on the right:

# %%
ts.resample('5min', closed='right', label='right').sum()
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:05:00    15
# 2000-01-01 00:10:00    40
# 2000-01-01 00:15:00    11
# Freq: 5T, dtype: int32

# %%
ts.resample('5min', closed='right', label='right', loffset='-1s').sum()
# Out:
# 1999-12-31 23:59:59     0
# 2000-01-01 00:04:59    15
# 2000-01-01 00:09:59    40
# 2000-01-01 00:14:59    11
# Freq: 5T, dtype: int32

# %% [markdown]
# **Open-High-Low-Close (OHLC) resampling**

# %% [markdown]
# In finance, a popular way to aggregate a time series is to compute four values for each
# bucket: the first (open), last (close), maximum (high), and minimal (low) values. By
# using the ohlc aggregate function you will obtain a DataFrame having columns con‐
# taining these four aggregates, which are efficiently computed in a single sweep of the
# data:

# %%
ts.resample('5min').ohlc()
# Out:
#                      open  high  low  close
# 2000-01-01 00:00:00     0     4    0      4
# 2000-01-01 00:05:00     5     9    5      9
# 2000-01-01 00:10:00    10    11   10     11

# %% [markdown]
# **Upsampling and Interpolation**

# %%
frame = pd.DataFrame(np.random.randn(2, 4),
        index=pd.date_range('1/1/2000', periods=2,
        freq='W-WED'),
        columns=['Colorado', 'Texas', 'New York', 'Ohio'])

# %%
frame
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-12  0.873290 -0.601661  0.933951  2.128898

# %%
df_daily = frame.resample('D').asfreq()

# %%
df_daily
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-06       NaN       NaN       NaN       NaN
# 2000-01-07       NaN       NaN       NaN       NaN
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12  0.873290 -0.601661  0.933951  2.128898

# %%
frame.resample('D').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-06 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-07 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-08 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-09 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-10 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-11 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-12  0.873290 -0.601661  0.933951  2.128898

# %%
frame.resample('D').ffill(limit=2)
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-06 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-07 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12  0.873290 -0.601661  0.933951  2.128898

# %%
frame.resample('W-THU').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-06 -0.704718 -1.455468  0.260556  1.095943
# 2000-01-13  0.873290 -0.601661  0.933951  2.128898

# %% [markdown]
# **Resampling with Periods**

# %%
frame = pd.DataFrame(np.random.randn(24, 4),
        index=pd.period_range('1-2000', '12-2001',
        freq='M'),
        columns=['Colorado', 'Texas', 'New York', 'Ohio'])

# %%
frame[:5]
# Out:
#          Colorado     Texas  New York      Ohio
# 2000-01  0.909700 -0.586151  0.397910 -0.225020
# 2000-02 -0.120775 -0.956010 -0.960644 -0.523399
# 2000-03  2.105669  0.364014 -0.862439  1.525740
# 2000-04 -1.154801 -0.394108  1.119238 -0.639867
# 2000-05  1.822035  0.943093 -0.165287 -0.543602

# %%
annual_frame = frame.resample('A-DEC').mean()

# %%
annual_frame
# Out:
#       Colorado     Texas  New York      Ohio
# 2000  0.010451  0.107607  0.165955 -0.332384
# 2001 -0.387873  0.222569  0.026969 -0.655484

# %%
annual_frame.resample('Q-DEC').ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q1  0.010451  0.107607  0.165955 -0.332384
# 2000Q2  0.010451  0.107607  0.165955 -0.332384
# 2000Q3  0.010451  0.107607  0.165955 -0.332384
# 2000Q4  0.010451  0.107607  0.165955 -0.332384
# 2001Q1 -0.387873  0.222569  0.026969 -0.655484
# 2001Q2 -0.387873  0.222569  0.026969 -0.655484
# 2001Q3 -0.387873  0.222569  0.026969 -0.655484
# 2001Q4 -0.387873  0.222569  0.026969 -0.655484

# %%
annual_frame.resample('Q-DEC', convention='end').ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q4  0.010451  0.107607  0.165955 -0.332384
# 2001Q1  0.010451  0.107607  0.165955 -0.332384
# 2001Q2  0.010451  0.107607  0.165955 -0.332384
# 2001Q3  0.010451  0.107607  0.165955 -0.332384
# 2001Q4 -0.387873  0.222569  0.026969 -0.655484

# %%
annual_frame.resample('Q-MAR').ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q4  0.010451  0.107607  0.165955 -0.332384
# 2001Q1  0.010451  0.107607  0.165955 -0.332384
# 2001Q2  0.010451  0.107607  0.165955 -0.332384
# 2001Q3  0.010451  0.107607  0.165955 -0.332384
# 2001Q4 -0.387873  0.222569  0.026969 -0.655484
# 2002Q1 -0.387873  0.222569  0.026969 -0.655484
# 2002Q2 -0.387873  0.222569  0.026969 -0.655484
# 2002Q3 -0.387873  0.222569  0.026969 -0.655484

# %% [markdown]
# **Moving Window Functions**

# %%
close_px_all = pd.read_csv('./book-support//examples/stock_px_2.csv', parse_dates=True, index_col=0)

# %%
close_px = close_px_all[['AAPL', 'MSFT', 'XOM']]

# %%
close_px
# Out:
#               AAPL   MSFT    XOM
# 2003-01-02    7.40  21.11  29.22
# 2003-01-03    7.45  21.14  29.24
# 2003-01-06    7.45  21.52  29.96
# 2003-01-07    7.43  21.93  28.95
# 2003-01-08    7.28  21.31  28.83
# ...            ...    ...    ...
# 2011-10-10  388.81  26.94  76.28
# 2011-10-11  400.29  27.00  76.27
# 2011-10-12  402.19  26.96  77.16
# 2011-10-13  408.43  27.18  76.37
# 2011-10-14  422.00  27.27  78.11
#
# [2214 rows x 3 columns]

# %%
close_px = close_px.resample('B').ffill()

# %%
close_px
# Out:
#               AAPL   MSFT    XOM
# 2003-01-02    7.40  21.11  29.22
# 2003-01-03    7.45  21.14  29.24
# 2003-01-06    7.45  21.52  29.96
# 2003-01-07    7.43  21.93  28.95
# 2003-01-08    7.28  21.31  28.83
# ...            ...    ...    ...
# 2011-10-10  388.81  26.94  76.28
# 2011-10-11  400.29  27.00  76.27
# 2011-10-12  402.19  26.96  77.16
# 2011-10-13  408.43  27.18  76.37
# 2011-10-14  422.00  27.27  78.11
#
# [2292 rows x 3 columns]

# %%
close_px.AAPL.plot()
close_px.AAPL.rolling(250).mean().plot()

# %%
close_px.AAPL.rolling(250).mean().plot()

# %%
appl_std250 = close_px.AAPL.rolling(250, min_periods=10).std()

# %%
appl_std250[5:12]
# Out:
# 2003-01-09         NaN
# 2003-01-10         NaN
# 2003-01-13         NaN
# 2003-01-14         NaN
# 2003-01-15    0.077496
# 2003-01-16    0.074760
# 2003-01-17    0.112368
# Freq: B, Name: AAPL, dtype: float64

# %%
appl_std250.plot()

# %% [markdown]
# In order to compute an expanding window mean, use the expanding operator instead
# of rolling. The expanding mean starts the time window from the beginning of the
# time series and increases the size of the window until it encompasses the whole series.
# An expanding window mean on the apple_std250 time series looks like this:

# %%
expanding_mean = appl_std250.expanding().mean()

# %%
close_px.rolling(60).mean().plot(logy=True, title='Stocks prices 60-day MA (log Y-axis)');

# %%
close_px.rolling('20D').mean()
# Out:
#                   AAPL       MSFT        XOM
# 2003-01-02    7.400000  21.110000  29.220000
# 2003-01-03    7.425000  21.125000  29.230000
# 2003-01-06    7.433333  21.256667  29.473333
# 2003-01-07    7.432500  21.425000  29.342500
# 2003-01-08    7.402000  21.402000  29.240000
# ...                ...        ...        ...
# 2011-10-10  389.351429  25.602143  72.527857
# 2011-10-11  388.505000  25.674286  72.835000
# 2011-10-12  388.531429  25.810000  73.400714
# 2011-10-13  388.826429  25.961429  73.905000
# 2011-10-14  391.038000  26.048667  74.185333
#
# [2292 rows x 3 columns]

# %% [markdown]
# **Exponentially Weighted Functions**

# %%
aapl_px = close_px.AAPL['2006':'2007']

# %%
aapl_px
# Out:
# 2006-01-02     71.89
# 2006-01-03     74.75
# 2006-01-04     74.97
# 2006-01-05     74.38
# 2006-01-06     76.30
#                ...
# 2007-12-25    198.80
# 2007-12-26    198.95
# 2007-12-27    198.57
# 2007-12-28    199.83
# 2007-12-31    198.08
# Freq: B, Name: AAPL, Length: 521, dtype: float64

# %%
ma60 = aapl_px.rolling(30, min_periods=20).mean()

# %%
ma60
# Out:
# 2006-01-02           NaN
# 2006-01-03           NaN
# 2006-01-04           NaN
# 2006-01-05           NaN
# 2006-01-06           NaN
#                  ...
# 2007-12-25    181.520333
# 2007-12-26    182.615000
# 2007-12-27    183.757333
# 2007-12-28    184.872000
# 2007-12-31    186.009667
# Freq: B, Name: AAPL, Length: 521, dtype: float64

# %%
ewma60 = aapl_px.ewm(span=30).mean()

# %%
ewma60
# Out:
# 2006-01-02     71.890000
# 2006-01-03     73.367667
# 2006-01-04     73.937767
# 2006-01-05     74.059619
# 2006-01-06     74.569360
#                  ...
# 2007-12-25    184.441771
# 2007-12-26    185.377786
# 2007-12-27    186.228897
# 2007-12-28    187.106387
# 2007-12-31    187.814362
# Freq: B, Name: AAPL, Length: 521, dtype: float64

# %%
ma60.plot(style='k--', label='Simple MA');
plt.legend()

# %%
ewma60.plot(style='k-', label='EW MA');
plt.legend()

# %% [markdown]
# **Binary Moving Window Functions**

# %%
spx_px = close_px_all['SPX']

# %%
spx_px
# Out:
# 2003-01-02     909.03
# 2003-01-03     908.59
# 2003-01-06     929.01
# 2003-01-07     922.93
# 2003-01-08     909.93
#                ...
# 2011-10-10    1194.89
# 2011-10-11    1195.54
# 2011-10-12    1207.25
# 2011-10-13    1203.66
# 2011-10-14    1224.58
# Name: SPX, Length: 2214, dtype: float64

# %%
spx_rets = spx_px.pct_change()

# %%
spx_rets
# Out:
# 2003-01-02         NaN
# 2003-01-03   -0.000484
# 2003-01-06    0.022474
# 2003-01-07   -0.006545
# 2003-01-08   -0.014086
#                 ...
# 2011-10-10    0.034125
# 2011-10-11    0.000544
# 2011-10-12    0.009795
# 2011-10-13   -0.002974
# 2011-10-14    0.017380
# Name: SPX, Length: 2214, dtype: float64

# %%
returns = close_px.pct_change()

# %%
returns
# Out:
#                 AAPL      MSFT       XOM
# 2003-01-02       NaN       NaN       NaN
# 2003-01-03  0.006757  0.001421  0.000684
# 2003-01-06  0.000000  0.017975  0.024624
# 2003-01-07 -0.002685  0.019052 -0.033712
# 2003-01-08 -0.020188 -0.028272 -0.004145
# ...              ...       ...       ...
# 2011-10-10  0.051406  0.026286  0.036977
# 2011-10-11  0.029526  0.002227 -0.000131
# 2011-10-12  0.004747 -0.001481  0.011669
# 2011-10-13  0.015515  0.008160 -0.010238
# 2011-10-14  0.033225  0.003311  0.022784
#
# [2292 rows x 3 columns]

# %%
corr = returns.AAPL.rolling(125, min_periods=100).corr(spx_rets)

# %%
corr.plot(title='Six-month AAPL return correlation to S&P 500');

# %% [markdown]
# Suppose you wanted to compute the correlation of the S&P 500 index with many
# stocks at once. Writing a loop and creating a new DataFrame would be easy but might
# get repetitive, so if you pass a Series and a DataFrame, a function like rolling_corr
# will compute the correlation of the Series (spx_rets, in this case) with each column
# in the DataFrame

# %%
corr = returns.rolling(125, min_periods=100).corr(spx_rets)

# %%
corr.plot(title='Six-month return correlations to S&P 500');

# %% [markdown]
# **User-Defined Moving Window Functions**

# %% [markdown]
# The apply method on rolling and related methods provides a means to apply an
# array function of your own devising over a moving window. The only requirement is
# that the function produce a single value (a reduction) from each piece of the array.
# For example, while we can compute sample quantiles using rolling(...).quan
# tile(q), we might be interested in the percentile rank of a particular value over the
# sample. The scipy.stats.percentileofscore function does just this

# %%
from scipy.stats import percentileofscore

# %%
score_at_2percent = lambda x: percentileofscore(x, 0.02)

# %%
result = returns.AAPL.rolling(250).apply(score_at_2percent)

# %%
result.plot(title=' Percentile rank of 2% AAPL return over one-year window');
